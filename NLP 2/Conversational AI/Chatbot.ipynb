# %%
import os, sys

# %%
os.unlink(nb_path)

# %%
from google.colab import drive
drive.mount('/content/mnt')
nb_path = '/content/nlpnotebooks'
# Out:
# Drive already mounted at /content/mnt; to attempt to forcibly remount, call drive.mount("/content/mnt", force_remount=True).

# %%
os.symlink('/content/mnt/My\ Drive/Colab\ Notebooks/NLP_2/Conversational_AI/', nb_path)
codepath = os.path.join(nb_path, 'codes')
sys.path.append('/content/mnt/My\ Drive/Colab\ Notebooks/NLP_2/Conversational_AI/codes')

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 645kB 5.7MB/s
# ...
#      |████████████████████████████████| 3.8MB 9.4MB/s
# ...
#      |████████████████████████████████| 1.0MB 35.2MB/s
# ...
#      |████████████████████████████████| 890kB 42.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=0af51573321695bc402e13318963a72681899a7a17bbd842b0a28f4d1aab8767
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
import numpy as np
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# %%
MAX_LENGTH = int(10000)

# %%
def set_seed(args):
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    if args.n_gpu > 0:
        torch.cuda.manual_seed_all(args.seed)

# %%
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/mnt/My\\ Drive/Colab\\ Notebooks/NLP_2/Conversational_AI/codes']

# %%
sys.path.append('/content/mnt/My\ Drive/Colab\ Notebooks/NLP_2/Conversational_AI/codes/')

# %%
cd /content/mnt/My\ Drive/Colab\ Notebooks/NLP_2/Conversational_AI/codes/
# Out:
# /content/mnt/My Drive/Colab Notebooks/NLP_2/Conversational_AI/codes

# %%
from main import Chatbot

# %%
chatbot = Chatbot()

# %% [markdown]
# # New Section

# %%
chatbot.generate_sentences()
# Out:
# Start Chatting......
# Hi How are you?
# Setting `pad_token_id` to 50256 (first `eos_token_id`) to generate sequence
# BOT >>>
# I'm a little bit older than I used to be, but my parents were pretty good at keeping me in school.
